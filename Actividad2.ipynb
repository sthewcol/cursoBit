# %%
dic_dep={1:"Antioquia",2:"Cundinamarca",3:"Quindio",4:"Valle"}
dic_cd={1:{1:"Medellin",2:"Yarumal",3:"Rionegro",4:"Jerico"},2:{1:"Soacha",2:"Facatativa",3:"Zipaquira",4:"Mosquera"},3:{1:"Armenia",2:"Salento",3:"Calarca",4:"Montenegro"},4:{1:"Cali",2:"Palmira",3:"Buga",4:"Cartago"}}
dic_opc={1:"Comidas",2:"Fauna",3:"Datos Historicos",4:"Musica"}



list_com_ant=["Bandeja paisa","Fríjoles antioqueños","Fríjoles con pezuña","Sancocho antioqueño"]
list_com_cun=["Ajiaco","Fritanga","Puchero","Sopa de pan"]
list_com_quin=["Sancocho","Calentao paisa","Arepa","Sudados"]
list_com_val=["Marranitas vallunas","Pandebonos vallunos","Manjar blanco valluno","Cholado valluno"]


list_fau_ant=["Zorro","Armadillo","Zariguella","Ocelote"]
list_fau_cun=["Oso Andino","Venado Sabanero","Nutria Neotropical","Colibri"]
list_fau_quin=["Mariposa achocolatada rayiblanca","Gupi","Iguana","Culebra falsa coral"]
list_fau_val=["Oso Perezoso","Oso de Anteojos","Nutria","Buitre de ciénaga"]


list_Hist_ant=["Zorro","Armadillo","Zariguella","Ocelote"]
list_Hist_cun=["Oso Andino","Venado Sabanero","Nutria Neotropical","Colibri"]
list_Hist_quin=["Mariposa achocolatada rayiblanca","Gupi","Iguana","Culebra falsa coral"]
list_Hist_val=["Oso Perezoso","Oso de Anteojos","Nutria","Buitre de ciénaga"]

list_mus_ant=["Zorro","Armadillo","Zariguella","Ocelote"]
list_mus_cun=["Oso Andino","Venado Sabanero","Nutria Neotropical","Colibri"]
list_mus_quin=["Mariposa achocolatada rayiblanca","Gupi","Iguana","Culebra falsa coral"]
list_mus_val=["Oso Perezoso","Oso de Anteojos","Nutria","Buitre de ciénaga"]



dict_termi={"Ajiaco":"Ajiaco es el nombre dado a unas sopas típicas de la América Latina",
            "Arepa":"La arepa es un alimento de origen precolombino de Colombia, Venezuela y Bolivia, hecho a base de masa de maíz seco molido o de harina de maíz precocida, de forma circular y aplanada. Es consumido de manera tradicional en las gastronomías de esos países",
            "Armadillo":"Los dasipódidos, conocidos comúnmente como armadillos, son una familia de mamíferos placentarios del orden Cingulata",
            "Bandeja paisa":"La bandeja paisa es el plato más representativo y la insignia de la gastronomía antioqueña, y es propio de esta región, Antioquia.",
            "Buitre de ciénaga":"Su nombre viene de la palabra Tupí Anhuma que significa ave negra y del latín cornutus que significa cornado en referencia al cuerno que presenta en la frente.",
            "Calentao paisa":"El calentado es un desayuno tradicional colombiano. Era el desayuno típico que comían nuestros ancestros en la región paisa para aprovechar las sobras de frijoles y arroz de la noche anterior. Los ingredientes que más se usan para preparar este plato son los frijoles, el arroz, el plátano y la carne, ya que es lo que más se come en la región paisa. Se sirve con huevo y arepa.",
            "Cholado valluno":"El Cholado valluno es un refrescante postre a base de frutas típico de Colombia y concretamente del Valle del Cauca y Cali.",
            "Colibri":"Los colibríes, también conocidos como picaflores, zumbadores, tucusitos, pájaros mosca, ermitaños o quindes, son un conjunto de aves apodiformes endémicas de América que cuenta con más de 300 especies",
            "Culebra falsa coral":"La coral ratonera, falsa coral o culebra real coralillo es una especie de reptil de la familia Colubridae. Habita en casi toda América, desde el sur de Canadá hasta Ecuador, Colombia y Venezuela, pasando por Estados Unidos, México y Centroamérica.",
            "Fríjoles antioqueños":"Una de las comidas colombianas que debes probar al menos una vez en la vida es la bandeja paisa la cual está compuesta por varios elementos que la hacen muy especial, por esta razón hoy te traemos la clásica receta de uno de sus componentes principales, frijoles antioqueños o paisas como también son conocidos dada la proximidad con dicha bandeja.",
            "Fríjoles con pezuña":"Los Fríjoles con Pezuña de cerdo, es una de las recetas típicas de la gastronomía del país y base de la bandeja paisa. Una receta que requiere de tiempo y paciencia pero en realidad la preparación no es tan complicada. ",
            "Fritanga":"La fritanga, también conocida como picada, es un platillo tradicional de Colombia, pero específicamente en la región que une los departamentos de Cundinamarca y Boyacá (cundiboyacense) se trata de un plato típico.",   
            "Gupi":"El guppy, lebistes o pez millón es un pez ovovivíparo de agua dulce procedente de Sudamérica que habita en zonas de corriente baja de ríos, lagos y charcas. Es muy conocido en el mundo de la acuariofilia puesto que su cuidado no ofrece grandes dificultades y se reproduce con muchísima facilidad.",
            "Iguana":"Iguana es un género de saurópsidos escamosos de la familia Iguanidae nativos de zonas tropicales de Centroamérica, Sudamérica y el Caribe.",
            "Manjar blanco valluno":"También es conocido como manjar de leche o simplemente Manjar. El manjar blanco es una crema dulce generalmente aromatizada con canela que se toma como postre.",
            "Mariposa achocolatada rayiblanca":"Sin informacion",
            "Marranitas vallunas2":"Se trata de un plato que también podemos encontrar en otros países, en Ecuador se llama Bolón, en Cuba fufú de plátano, y en otros lugares de Colombia se llaman puerquitas. los ingredientes para la receta son muy fáciles de conseguir y su preparación es muy simple aunque requiere cierta precisión. El punto del plátano es la clave, tiene que salirnos crujiente por fuera y blandito por dentro.",
            "Nutria":"Los lutrinos, conocidos comúnmente como nutrias, son una subfamilia de mamíferos carnívoros de la gran familia Mustelidae. Existen 13 especies de nutrias repartidas en 7 géneros, ​ con una distribución de la población prácticamente mundial.",
            "Nutria Neotropical2":"El lobito de río, también conocido como nutria del noroeste, nutria neotropical, perro de agua, pisua o mallu-puma, es un mustélido de la subfamilia Lutrinae, que se encuentra en Centro y Sudamérica, desde el sur de México hasta Uruguay y el centro de Argentina.",
            "Ocelote":"El ocelote es una especie de mamífero carnívoro de la familia Felidae. Se encuentra ampliamente distribuido en América principalmente en ambientes tropicales, donde se diferencia en numerosas subespecies.",
            "Oso Andino":"El oso de anteojos, también conocido como oso frontino, oso andino, oso sudamericano, ucumari y jukumari, es una especie de mamífero de la familia Ursidae.​ Es la única especie viviente de su género.",
            "Oso de Anteojos":"El oso de anteojos, también conocido como oso frontino, oso andino, oso sudamericano, ucumari y jukumari, es una especie de mamífero de la familia Ursidae.​ Es la única especie viviente de su género.",
            "Oso Perezoso":"El oso bezudo​ u oso perezoso​ es una especie de mamífero carnívoro de la familia de los úrsidos. Es un oso de hábitos preferentemente nocturnos que vivió históricamente en las praderas y bosques de llanura de la India, Nepal, Bangladés, Sri Lanka y Bután.",
            "Pandebonos vallunos":"Son muy fáciles de preparar, los ingredientes son de los que habitualmente solemos tener en casa. Y podemos hacer muchos de golpe ya que también se pueden congelar para tomar en otro momento.",
            "Puchero":"El Puchero es otro de los platos típicos de Cundinamarca que se destaca por su complejidad y sabor. Generalmente incluye carne de res, pollo, cerdo, plátano, yuca, papas, maíz, chorizo y repollo, y dirás que se parece mucho a la fritanga, y sí, algo, tiene casi los mismos ingredientes, solo que este plato se sirve cocinado con ahogado (sofrito de cebolla, tomate, ajo y condimentos que es muy común en muchos platos de la gastronomía colombiana), arroz blanco y aguacate.",
            "Sancocho":"El sancocho es una sopa hecha con carnes, tubérculos, verduras y condimentos. Entre sus orígenes parecen estar el ajiaco taíno, el cocido español, la olla podrida española, y los estofados corso, irlandés, danés, alemán, italiano y francés.",
            "Sancocho antioqueño":"Este Sancocho Antioqueño o Paisa es la variación que hacemos en el departamento de Antioquia de Colombia, la región donde nací y crecí. Hay diferentes recetas de este sancocho cada familia tiene su forma favorita de prepararlo. Esta es la receta de mi abuela y la forma en que mi mamá y mis tías hacen Sancocho Paisa. Mi abuela servía el sancocho con arroz blanco, ají y aguacate.",
            "Sopa de pan":"Las sopas de pan o también conocidas como sopas de los siete potajes, son un tipo de lasaña por la estructura que tiene de pisos donde se intercala el pan con el resto de ingredientes.",
            "Sudados":"El sudado de pescado es una sopa típica de la gastronomía peruana, aunque también se encuentra recogida en las cocinas de otros países latinoamericanos, como en Ecuador.",
            "Venado Sabanero":"El venado cola blanca, ciervo cola blanca, ciervo de Virginia, venado de Virginia o venado gris es una especie de mamífero artiodáctilo de la familia de los cérvidos.",
            "Zariguella":"La zarigüeya es un pequeño mamífero marsupial muy popular en América. Es un animal de hábitos nocturnos con un aspecto similar al de una rata",
            "Zorro":"Los vulpinos son una tribu de mamíferos carnívoros incluidos en la familia de los cánidos. Se conocen comúnmente como zorros, zorras, raposos o raposas."}

# %%
def opc():
    print("****SELECCIONE UNA CIUDAD****")
    
    for i in dic_opc.items():
        print (i[0], " ", i[1])
        
    a= input()
    
    if  a.isdigit():
        b=int(a)
        if b in dic_opc:
            return (b)
        else:
            print("Digite una opcion valida")
            opc()
    else:
        print("Digite un numero de la lista")
        opc()


def cd(dep):
    print("****SELECCIONE UNA CIUDAD****")
    
    for i in dic_cd[dep].items():
        print (i[0], " ", i[1])
        
    a= input()
    
    if  a.isdigit():
        b=int(a)
        if b in dic_cd[dep]:
            opc()
        else:
            print("Digite una opcion valida")
            cd(dep)
    else:
        print("Digite un numero de la lista")
        cd(dep)
        

def ini():
    print("****SELECCIONE UN DEPARTAMENTO****")
    for i in dic_dep.items():
        print (i[0], " ", i[1])
    a= input()
    
    if  a.isdigit():
        b=int(a)
        
        if b in dic_dep:
            cd(b)
        else:
            print("Digite una opcion valida")
            ini()
    else:
        print("Digite un numero de la lista")
        ini()

# %%
ini()
# Out:
# ****SELECCIONE UN DEPARTAMENTO****
# 1   Antioquia
# 2   Cundinamarca
# 3   Quindio
# 4   Valle
# 1
# ****SELECCIONE UNA CIUDAD****
# 1   Medellin
# 2   Yarumal
# 3   Rionegro
# 4   Jerico
# 1
# ****SELECCIONE UNA CIUDAD****
# 1   Comidas
# 2   Fauna
# 3   Datos Historicos
# 4   Musica
# hjk
# Digite un numero de la lista
# ****SELECCIONE UNA CIUDAD****
# 1   Comidas
# 2   Fauna
# 3   Datos Historicos
# 4   Musica
# 789
# Digite una opcion valida
# ****SELECCIONE UNA CIUDAD****
# 1   Comidas
# 2   Fauna
# 3   Datos Historicos
# 4   Musica
# 1
